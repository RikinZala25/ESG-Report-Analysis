# %%
import numpy as np
import pandas as pd
import json

# %%
# Read and print the stock tickers that make up S&P500
tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

columns_to_remove = ["Headquarters Location", "Date added", "CIK", "Founded", "GICS Sector",	"GICS Sub-Industry"]
tickers = tickers.drop(columns=columns_to_remove)

tickers = tickers.rename(columns={"Symbol":"value", "Security": "label"})

# %%
tickers
# Out:
#     value                 label
# 0     MMM                    3M
# 1     AOS           A. O. Smith
# 2     ABT                Abbott
# 3    ABBV                AbbVie
# 4     ACN             Accenture
# ..    ...                   ...
# 497   YUM           Yum! Brands
# 498  ZBRA    Zebra Technologies
# 499   ZBH         Zimmer Biomet
# 500  ZION  Zions Bancorporation
# 501   ZTS                Zoetis
#
# [502 rows x 2 columns]

# %%
for index, row in tickers.iterrows():
    value = row['value']
    label = row['label']
    print('{{ value: "{0}", label: "{1}" }},'.format(value, label))
# Out:
# { value: "MMM", label: "3M" },
# { value: "AOS", label: "A. O. Smith" },
# { value: "ABT", label: "Abbott" },
# { value: "ABBV", label: "AbbVie" },
# { value: "ACN", label: "Accenture" },
# { value: "ADM", label: "ADM" },
# { value: "ADBE", label: "Adobe Inc." },
# { value: "ADP", label: "ADP" },
# { value: "AES", label: "AES Corporation" },
# { value: "AFL", label: "Aflac" },
# { value: "A", label: "Agilent Technologies" },
# { value: "ABNB", label: "Airbnb" },
# { value: "APD", label: "Air Products and Chemicals" },
# { value: "AKAM", label: "Akamai" },
# { value: "ALK", label: "Alaska Air Group" },
# { value: "ALB", label: "Albemarle Corporation" },
# { value: "ARE", label: "Alexandria Real Estate Equities" },
# { value: "ALGN", label: "Align Technology" },
# { value: "ALLE", label: "Allegion" },
# { value: "LNT", label: "Alliant Energy" },
# { value: "ALL", label: "Allstate" },
# { value: "GOOGL", label: "Alphabet Inc. (Class A)" },
# ...

# %%
options = []

for index, row in tickers.iterrows():
    value = row['value']
    label = row['label']
    options.append({"value": value, "label": label})

with open('./outputs_json/options.json', 'w') as json_file:
    json.dump(options, json_file, indent=4)
